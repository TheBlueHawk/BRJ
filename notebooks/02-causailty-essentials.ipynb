# %% [markdown]
# # Week 2 - Causal Inference Essentials
#
# This is an introduction to the basics of estimating linear models for causal inference. The goal of this notebook is to try to estimate the effect of education on income, which has always been a key question in economic research

# %% [markdown]
# ## Set up and load data

# %%
# Common imports
import numpy as np
import os
import pandas as pd

# To plot pretty figures
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib as mpl
import matplotlib.pyplot as plt
#%matplotlib notebook
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

import seaborn as sns
sns.set_theme()
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings = lambda *a, **kw: None

# to make this notebook's output identical at every run
np.random.seed(42)

# %% [markdown]
# ## State Level Data

# %% [markdown]
# We start from a dataset at the state level containing information from 1990. This data contains
#
# - region of the country where the state is located
# - average SAT scores ($csat$)
# - percentage of high school graduate taking SAT ($percent$)
# - average per-pupile expenditure in primary and secondary education ($expanse$)
# - median household income in thousands ($income$)
# - percentage of adults with high school diploma ($high$)
# - percentage of adults with college degree ($college$)

# %%
df = pd.read_stata('https://dss.princeton.edu/training/states.dta')

# %% [markdown]
# Data Set Characteristics:

# %%
df.head(10)
# Out:
#     region  csat  percent  expense  income       high    college
# 0    South   991        8     3627  27.498  66.900002  15.700000
# 1     West   920       41     8330  48.254  86.599998  23.000000
# 2     West   932       26     4309  32.093  78.699997  20.299999
# 3    South  1005        6     3700  24.643  66.300003  13.300000
# 4     West   897       47     4491  41.716  76.199997  23.400000
# 5     West   959       29     5064  35.123  84.400002  27.000000
# 6  N. East   897       81     7602  48.618  79.199997  27.200001
# 7    South   892       61     5865  40.641  77.500000  21.400000
# 8      NaN   840       71     9259  35.807  73.099998  33.299999
# 9    South   882       48     5276  32.027  74.400002  18.299999

# %%
df.describe()
# Out:
#               csat    percent      expense     income       high    college
# count    51.000000  51.000000    51.000000  51.000000  51.000000  51.000000
# mean    944.098039  35.764706  5235.960784  33.956569  76.260788  20.021568
# std      66.934970  26.192814  1401.155037   6.423134   5.588741   4.165780
# min     832.000000   4.000000  2960.000000  23.465000  64.300003  12.300000
# 25%     888.000000  11.000000  4352.500000  29.875000  73.500000  17.300000
# 50%     926.000000  26.000000  5000.000000  33.452000  76.699997  19.299999
# 75%     997.000000  60.500000  5794.000000  36.919500  80.099998  22.900000
# max    1093.000000  81.000000  9259.000000  48.618000  86.599998  33.299999

# %%
y = df['income']
x = df['college']

# %% [markdown]
# #### Explore your data

# %%
sns.lineplot(x=x, y=y, ci = None)
# Out:
# <AxesSubplot: xlabel='college', ylabel='income'>

# %% [markdown]
# **What other relations can be helpful to explore before running the analysis?**

# %%
x1 = df['expense']
sns.lineplot(x = x1, y=y, ci=None)
# Out:
# <AxesSubplot: xlabel='expense', ylabel='income'>

# %% [markdown]
# #### Running the first regression
#
# To run simple regressions we will youse the package *statsmodels*. We start by running a simple regression of median income on the percentage of adults with a college degree:
#
# $$income_i = \beta_0 + \beta_1 college_i + \varepsilon_i$$

# %%
import statsmodels.formula.api as smf
from statsmodels.iolib.summary2 import summary_col

res = smf.ols("income ~ college", data=df).fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 income   R-squared:                       0.523
# Model:                            OLS   Adj. R-squared:                  0.514
# Method:                 Least Squares   F-statistic:                     53.78
# Date:                Sun, 09 Oct 2022   Prob (F-statistic):           2.02e-09
# Time:                        18:06:45   Log-Likelihood:                -147.83
# No. Observations:                  51   AIC:                             299.7
# Df Residuals:                      49   BIC:                             303.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     11.6260      3.109      3.739      0.000       5.378      17.874
# college        1.1153      0.152      7.333      0.000       0.810       1.421
# ==============================================================================
# Omnibus:                        1.515   Durbin-Watson:                   2.271
# Prob(Omnibus):                  0.469   Jarque-Bera (JB):                0.740
# Skew:                           0.028   Prob(JB):                        0.691
# Kurtosis:                       3.588   Cond. No.                         102.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# **Causal Interpretation:** The main coefficient of interest is the one on $college$. This result implies that, on average, an increase by 1 percentage point in college graduates increases median household income by \$1'115

# %%
sns.regplot(x=x, y=y)
# Out:
# <AxesSubplot: xlabel='college', ylabel='income'>

# %% [markdown]
# One potential source of bias could be the number of adults with a high school degree (why?). Luckly, we have the data on high school graduates and we can control for this in our regression.
#
# > The number of people with high school degree could explain part of the income: if the majority of people not having a college degree don't even have a high school degree we can reasonably expect an even lower income.

# %%
res_con1 = smf.ols("income ~ college + high", data = df).fit()
res_con1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 income   R-squared:                       0.545
# Model:                            OLS   Adj. R-squared:                  0.526
# Method:                 Least Squares   F-statistic:                     28.76
# Date:                Sun, 09 Oct 2022   Prob (F-statistic):           6.17e-09
# Time:                        18:09:06   Log-Likelihood:                -146.63
# No. Observations:                  51   AIC:                             299.3
# Df Residuals:                      48   BIC:                             305.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.8069      8.744     -0.092      0.927     -18.389      16.775
# college        0.9722      0.177      5.485      0.000       0.616       1.329
# high           0.2006      0.132      1.518      0.135      -0.065       0.466
# ==============================================================================
# Omnibus:                        0.043   Durbin-Watson:                   2.308
# Prob(Omnibus):                  0.979   Jarque-Bera (JB):                0.171
# Skew:                           0.062   Prob(JB):                        0.918
# Kurtosis:                       2.745   Cond. No.                     1.12e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.12e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# **How did the coefficient on $college$ change? Did it change in the direction you expected?**
#
# > The coefficient on college changed as expected: the number of person with an high school degree among the non-college graduate population positvely affect the final income and explains part of the data. Despite that college degree remains the main factor.

# %% [markdown]
# **Why could it not be a good idea to include the percentage of high school graduate in the regression? What other variables would you include?**
#
# > College graduate also have a high school degree, this could lead to some form of double counting.

# %%
res_con2 = smf.ols("income ~ college + expense", data=df).fit()
res_con2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 income   R-squared:                       0.602
# Model:                            OLS   Adj. R-squared:                  0.585
# Method:                 Least Squares   F-statistic:                     36.28
# Date:                Sun, 09 Oct 2022   Prob (F-statistic):           2.51e-10
# Time:                        20:01:03   Log-Likelihood:                -143.23
# No. Observations:                  51   AIC:                             292.5
# Df Residuals:                      48   BIC:                             298.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     10.0767      2.914      3.458      0.001       4.217      15.936
# college        0.7552      0.183      4.132      0.000       0.388       1.123
# expense        0.0017      0.001      3.079      0.003       0.001       0.003
# ==============================================================================
# Omnibus:                        9.850   Durbin-Watson:                   2.077
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):               14.036
# Skew:                          -0.576   Prob(JB):                     0.000895
# Kurtosis:                       5.297   Cond. No.                     2.73e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.73e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
print(summary_col([res,res_con1, res_con2]))
# Out:
# ============================================
#                income I income II income III
# --------------------------------------------
# Intercept      11.6260  -0.8069   10.0767
#                (3.1090) (8.7444)  (2.9143)
# R-squared      0.5232   0.5451    0.6019
# R-squared Adj. 0.5135   0.5261    0.5853
# college        1.1153   0.9722    0.7552
#                (0.1521) (0.1773)  (0.1828)
# expense                           0.0017
#                                   (0.0005)
# high                    0.2006
#                         (0.1321)
# ============================================
# Standard errors in parentheses.

# %% [markdown]
# **What are other problems that come up when using this regression to answer the initial research question?**
# > Some relations might not be linear, e.g. marginal benefits of additional \$ spent in education

# %% [markdown]
# ## Individual Level Data

# %% [markdown]
# In the second part we use data from the National Longitudinal Survey. In particular, we have a panel of young women who were between 14 and 26 years of age in 1988. We first have a look at our data and prepare them for the analysis.

# %%
df = pd.read_stata('https://www.stata-press.com/data/r16/nlsw88.dta')
df_labels = pd.read_stata('https://www.stata-press.com/data/r16/nlsw88.dta', iterator=True).variable_labels()

# %%
df.head(20)
# Out:
#     idcode  age   race  married  never_married  grade          collgrad  \
# 0        1   37  black   single              0   12.0  not college grad
# 1        2   37  black   single              0   12.0  not college grad
# 2        3   42  black   single              1   12.0  not college grad
# 3        4   43  white  married              0   17.0      college grad
# 4        6   42  white  married              0   12.0  not college grad
# 5        7   39  white  married              0   12.0  not college grad
# 6        9   37  white   single              0   12.0  not college grad
# 7       12   40  white  married              0   18.0      college grad
# 8       13   40  white  married              0   14.0  not college grad
# 9       14   40  white  married              0   15.0  not college grad
# 10      15   39  white  married              0   16.0      college grad
# 11      16   40  white  married              0   15.0  not college grad
# 12      18   40  white  married              0   15.0  not college grad
# 13      19   40  white   single              0   15.0  not college grad
# 14      20   39  white  married              0   15.0  not college grad
# 15      22   41  white  married              0   15.0  not college grad
# 16      23   42  white  married              0   15.0      college grad
# 17      24   41  white  married              0   14.0      college grad
# 18      25   42  white  married              0   14.0      college grad
# 19      36   37  white   single              1   12.0  not college grad
#
#     south     smsa  c_city                industry              occupation  \
# 0       0     SMSA       0  Transport/Comm/Utility              Operatives
# 1       0     SMSA       1           Manufacturing               Craftsmen
# 2       0     SMSA       1           Manufacturing                   Sales
# 3       0     SMSA       0   Professional Services                   Other
# 4       0     SMSA       0           Manufacturing              Operatives
# 5       0     SMSA       0   Professional Services                   Sales
# 6       0     SMSA       1  Transport/Comm/Utility          Managers/admin
# 7       0     SMSA       0   Professional Services          Managers/admin
# 8       0     SMSA       0   Professional Services                   Sales
# 9       0     SMSA       0   Professional Services  Professional/technical
# 10      0     SMSA       0   Professional Services  Professional/technical
# 11      0     SMSA       0   Professional Services  Professional/technical
# 12      0     SMSA       0  Wholesale/Retail Trade               Craftsmen
# 13      0     SMSA       0   Professional Services  Professional/technical
# 14      0     SMSA       0   Professional Services  Professional/technical
# 15      0     SMSA       0   Professional Services  Professional/technical
# 16      0  nonSMSA       0   Professional Services  Professional/technical
# 17      0     SMSA       0   Professional Services  Professional/technical
# 18      0     SMSA       1   Professional Services  Professional/technical
# 19      0     SMSA       0     Business/Repair Svc      Clerical/unskilled
#
#        union       wage  hours    ttl_exp     tenure
# 0      union  11.739125   48.0  10.333334   5.333333
# 1      union   6.400963   40.0  13.621795   5.250000
# 2        NaN   5.016723   40.0  17.730770   1.250000
# 3      union   9.033813   42.0  13.211537   1.750000
# 4   nonunion   8.083731   48.0  17.820513  17.750000
# 5   nonunion   4.629630   30.0   7.326923   2.250000
# 6      union  10.491142   40.0  19.044870  19.000000
# 7   nonunion  17.206116   45.0  15.557693  14.166667
# 8   nonunion  13.083735    8.0  14.250000   5.500000
# 9   nonunion   7.745568   50.0   7.384615   2.250000
# 10     union  16.795479   16.0  15.769231   8.416667
# 11  nonunion  15.483090   40.0  16.384615  13.833333
# 12  nonunion   5.233495   40.0   7.750000   7.750000
# 13     union  10.161026   40.0  14.211538   5.583333
# 14     union   9.661837    4.0  15.858974   4.666667
# 15  nonunion   9.057972   32.0  15.012821   3.000000
# 16  nonunion   8.051530   45.0  15.346155   8.083333
# 17  nonunion  11.095006   24.0  16.467947   3.416667
# 18  nonunion   9.581316   40.0  17.750000   5.416667
# 19       NaN   4.180602   40.0  15.935898   0.916667

# %%
df_labels
# Out:
# {'idcode': 'NLS id',
#  'age': 'age in current year',
#  'race': 'race',
#  'married': 'married',
#  'never_married': 'never married',
#  'grade': 'current grade completed',
#  'collgrad': 'college graduate',
#  'south': 'lives in south',
#  'smsa': 'lives in SMSA',
#  'c_city': 'lives in central city',
#  'industry': 'industry',
#  'occupation': 'occupation',
#  'union': 'union worker',
#  'wage': 'hourly wage',
#  'hours': 'usual hours worked',
#  'ttl_exp': 'total work experience',
#  'tenure': 'job tenure (years)'}

# %%
df.industry.value_counts()
# Out:
# Professional Services      824
# Manufacturing              367
# Wholesale/Retail Trade     333
# Finance/Ins/Real Estate    192
# Public Administration      176
# Personal Services           97
# Transport/Comm/Utility      90
# Business/Repair Svc         86
# Construction                29
# Ag/Forestry/Fisheries       17
# Entertainment/Rec Svc       17
# Mining                       4
# Name: industry, dtype: int64

# %%
df.occupation.value_counts()
# Out:
# Sales                     726
# Professional/technical    317
# Laborers                  286
# Managers/admin            264
# Operatives                246
# Other                     187
# Clerical/unskilled        102
# Craftsmen                  53
# Transport                  28
# Service                    16
# Farm laborers               9
# Household workers           2
# Farmers                     1
# Name: occupation, dtype: int64

# %%
df.race.value_counts()
# Out:
# white    1637
# black     583
# other      26
# Name: race, dtype: int64

# %%
##Drop missing observations

df_nomiss = df.dropna(subset=['collgrad', 'wage'])

# %% [markdown]
# #### Explore the data

# %%
y = df_nomiss['wage']
x = df_nomiss['collgrad']
sns.catplot(x = 'collgrad', y ='wage', kind = 'bar', data = df_nomiss, ci=None)

# %%
plt.hist(y, bins=30)
plt.xlabel("Hourly Wage", size=12)
plt.ylabel('Count', size=12)
plt.show()

# %% [markdown]
# #### Estimation

# %%
res = smf.ols("wage ~ C(collgrad)", data=df_nomiss).fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   wage   R-squared:                       0.071
# Model:                            OLS   Adj. R-squared:                  0.071
# Method:                 Least Squares   F-statistic:                     172.4
# Date:                Sun, 09 Oct 2022   Prob (F-statistic):           5.26e-38
# Time:                        20:13:30   Log-Likelihood:                -7034.2
# No. Observations:                2246   AIC:                         1.407e+04
# Df Residuals:                    2244   BIC:                         1.408e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       6.9106      0.134     51.572      0.000       6.648       7.173
# C(collgrad)[T.college grad]     3.6155      0.275     13.132      0.000       3.076       4.155
# ==============================================================================
# Omnibus:                     1612.161   Durbin-Watson:                   1.970
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            24903.685
# Skew:                           3.295   Prob(JB):                         0.00
# Kurtosis:                      17.923   Cond. No.                         2.51
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# **Causal Interpretation:** On average, having a college degree increases hourly wages by \$3.6

# %% [markdown]
# **What is the identification assumption behind this interpretation? Is it likely to be satisfied or not? Why?**
# > The assumtion is that there are no other confounding factors, which is really unlikely.
# > It's reasonable to expect that a college degree positively influence the hourly wage but other factors will really likely play a big role too.

# %%
res1 = smf.ols("wage ~ C(collgrad) + union", data=df_nomiss).fit()
res2 = smf.ols("wage ~ C(collgrad) + c_city", data=df_nomiss).fit()
res3 = smf.ols("wage ~ C(collgrad) + race", data=df_nomiss).fit()

# %%
print(summary_col([res,res1,res2,res3]))
# Out:
# ================================================================
#                              wage I  wage II  wage III wage IIII
# ----------------------------------------------------------------
# C(collgrad)[T.college grad] 3.6155   3.4296   3.5907   3.5318
#                             (0.2753) (0.2070) (0.2759) (0.2757)
# Intercept                   6.9106   6.4399   6.8146   7.1769
#                             (0.1340) (0.1122) (0.1516) (0.1540)
# R-squared                   0.0714   0.1478   0.0721   0.0767
# R-squared Adj.              0.0709   0.1469   0.0713   0.0754
# c_city                                        0.3493
#                                               (0.2581)
# race[T.black]                                          -0.9563
#                                                        (0.2678)
# race[T.other]                                          0.1514
#                                                        (1.0942)
# union[T.union]                       1.1334
#                                      (0.2074)
# ================================================================
# Standard errors in parentheses.

# %% [markdown]
# ### Residuals

# %% [markdown]
# So far we have assumed *homoskedastic* errors, meaning that we assumed the variance of the error term in our regression to be the same across observations and to be independent on the values of the explanatory variable. To investigate if this is the case, we need to calculate the residuals:
#
# $$e_i = y_i - \hat{y}_i$$
#
# where $\hat{y}_i$ are the predicted values of the wage. Once we have the residuals, one way to investigate if the errors are homoskedastic or not is to plot the fitted value of the dependent variable against the residuals form the regression.

# %%
yhat = res.predict()
resid = y - yhat

resid_plot = sns.scatterplot(x=resid, y=yhat)
resid_plot.set(xlabel='Residuals', ylabel='Predicted Wage')
plt.show()

# %%
plt.hist(resid, bins=30, density=True)
plt.xlabel("Residuals", size=12)
plt.ylabel('Density', size=12)
plt.show()

# %% [markdown]
# The errors from our regression present evidence of mild heteroskedasticity. Therefore, to correctly estimate the causal effect of interest, we need to corrct for it by estimating the covariance matrix in a *robust* way.

# %%
res_rob = smf.ols("wage ~ C(collgrad)", data=df_nomiss).fit(cov_type='HC1')
print(summary_col([res,res_rob]))
# Out:
# =============================================
#                              wage I  wage II
# ---------------------------------------------
# Intercept                   6.9106   6.9106
#                             (0.1340) (0.1276)
# C(collgrad)[T.college grad] 3.6155   3.6155
#                             (0.2753) (0.3024)
# R-squared                   0.0714   0.0714
# R-squared Adj.              0.0709   0.0709
# =============================================
# Standard errors in parentheses.
